# %%
name=input("")
# print(name)
# Out:
#  dua

# %%
a=input("enter number")
b=input("enter number")
print(a+b)
# Out:
# enter number 3
# enter number 4
# 34

# %%
num1=int(input("enter number"))
num2=int(input("enter number"))
print(num1+num2)
# Out:
# enter number 4
# enter number 6
# 10

# %%
"""you are 
the bitch"""
# Out:
# 'you are \nthe bitch'

# %% [markdown]
# # string

# %%
name="hira"
age="21"
print(
name)
print(age)
# Out:
# hira
# 21

# %%
print(name,age)
# Out:
# hira 21

# %% [markdown]
# # string concatenation

# %%
x="dua"
y="liaqat"
print(x + " " + y)
# Out:
# dua liaqat

# %%
print("dua " *5)
# Out:
# dua dua dua dua dua

# %%
x="dua liaqat"
print(x[5])
# Out:
# i

# %%
a="malika liaqat"
print(a[7])
# Out:
# l

# %%
a="malika liaqat"
print(a[-3])
# Out:
# q

# %%
z="my seif dua liaqat"
print(z[0:2])
# Out:
# my

# %%
z="my self dua liaqat"
# print(z[2:6])
print(len(z))
# Out:
# 18

# %%
z="                 my name is dua liaqat   "
print(z.strip())
print(z.upper())
print(z.lower())
# Out:
# my name is dua liaqat
#                  MY NAME IS DUA LIAQAT
#                  my name is dua liaqat

# %%
m="dua liaqat"
print(m.replace("liaqat","malika"))
# Out:
# dua malika

# %%
m="dua liaqat"
print(m.replace("ua","ho"))
# Out:
# dho liaqat

# %%
k="123456789"
print(k.replace("7","8"))
# Out:
# 123456889

# %%
z = " malika liaqat is vert bRAVE GIRL"
print(z.split())
# Out:
# ['malika', 'liaqat', 'is', 'vert', 'bRAVE', 'GIRL']

# %%
text = " ai is ver powerful language "
# print(text.find("is"))
# print ("ver " in text)/
print("dua" in text)
# Out:
# False

# %%
name="dua"
age="21"
# print("my name is",name ,"and i am ",21)
print(f"my name is {name} and i am {age}")
# Out:
# my name is dua and i am 21

# %%
j="what the actual thiing is this"
print("actual" in j)
# Out:
# True

# %%
print("dua\nliaqat")
print("dua\tliaqat")
print("dua\"liaqat")
# Out:
# dua
# liaqat
# dua	liaqat
# dua"liaqat

# %%
name=5j
print(type(name))
# Out:
# <class 'complex'>
