# %% [markdown]
# # functions

# %%
def greet():
    print("hello")
greet()
# Out:
# hello

# %% [markdown]
# # add

# %%
a=eval(input("enter no"))
b=eval(input("enter no2:"))
def add(a,b):
 return a+b
print(add(a,b))
# Out:
# enter no 4
# enter no2: 3
# 7

# %%
def dua():
    x=2
    print(x)
dua()
# Out:
# 2

# %%
x=5
def show():
    print(x)
show()
# Out:
# 5

# %% [markdown]
# # change

# %%
x=10
def change():
    global x
    x=20
    
change()
print(x)
# Out:
# 20

# %% [markdown]
# # square

# %%
square=lambda x:x*x
print(square(4))
# Out:
# 16

# %%
x=eval(input("enter number"))
def square():
    return x*x
    print(square(x))
square()
# Out:
# enter number 4
# 16

# %%
a=[1,2,3,4]
y=list(map(lambda x: x*2,a))
print(y)
# Out:
# [2, 4, 6, 8]

# %%
a=[1,2,3,4,5]
y=list(filter(lambda x: x%2==0,a))
print(y)
# Out:
# [2, 4]

# %%
class student:
    name ="ali"
    age= 20
# s1=student()
print(student.name)
print(student.age)
# Out:
# ali
# 20

# %%
#instant variable har object ka apna data ...sb object per operate ho ga
class student:
    def data(self,name,age):
        self.z=name
        self.q=age
# self jo hai wo object ko refer ker ga like self a jo ha yaha name object ko shoe kery ga

    def show(self):
        print(self.z,self.q)
a=student()
a. data("ali",20)
a.show()
# Out:
# ali 20

# %%
class Student:
    school = "ABC School"

    def __init__(self, name):
        self.name = name


s1 = Student("dua")
s2 = Student("ali")

print(s1.name, s1.school)
print(s2.name, s2.school)
# Out:
# dua ABC School
# ali ABC School

# %%
class Student:
    
    @classmethod
    def school(self,name):
        self.soo = name

Student.school("XYZ School")
print(Student.soo)
# Out:
# XYZ School

# %%
# constructor(__init__())
class student:
    def __init__(self,name,age):
        self.na=name
        self.aa=age
a= student ("malika",20)
print(a.na)
print(a.aa)
# class Student:
    
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
        
# s1 = Student("Ali", 20)

# print(s1.name)
# print(s1.age)
# Out:
# malika
# 20

# %%
class dua:
    def __del__(self):
        print(" code destroye")
d=dua()
del d
# Out:
#  code destroye
