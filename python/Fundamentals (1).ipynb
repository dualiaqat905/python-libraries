# %% [markdown]
# # **Python Fundamentals**

# %% [markdown]
# # *Value, Expression and Statement*

# %% [markdown]
# ####  Q:   Values kya hoti hain?
# ##### Ans: Value koi bhi data hota hai jo program use karta hai.

# %% [markdown]
# ##### Types:
#
# ##### Integer → 10
#
# ##### Float → 3.14
#
# ##### String → "Hello"
#
# ##### Boolean → True / False

# %%
10
3.14
"Hello"
True
# Out:
# True

# %% [markdown]
# #### Q: Expression kya hoti hai?
# ##### Ans: Expression wo combination hota hai jo evaluate ho kar value deta hai.

# %%
5 + 3
10 * 2
"Hi" + "There"
# Out:
# 'HiThere'

# %% [markdown]
# #### Q: Statement kya hota hai?
# ##### Ans: Statement instruction hota hai jo Python ko kaam karne ko bolta hai.

# %%
x = 2
print(x)
# Out:
# 2

# %% [markdown]
# # *Numbers*

# %% [markdown]
# ##### Python ma 3 tarhan k Numbers hota hain

# %% [markdown]
# #### 1) Integer (int)
# #####  Whole numbers.

# %%
10
-25
1000
# Out:
# 1000

# %% [markdown]
# #### 2) Float (float)
# ##### Decimal numbers.

# %%
3.14
-2.5
0.0
# Out:
# 0.0

# %% [markdown]
# #### 3) Complex (advanced)

# %%
2 + 3j
# Out:
# (2+3j)

# %% [markdown]
# # *Booleans*

# %% [markdown]
# ##### Boolean sirf 2 values hoti hain
# ###### True
# ###### False

# %%
5 > 6
# Out:
# False

# %% [markdown]
# # *Strings*

# %% [markdown]
# #### String text hota hai.

# %%
"2" + "2"
# Out:
# '22'

# %%
"Hello"
'Python'
"2"
"2"
# Out:
# '2'

# %%
"Hello" + " World"
# Out:
# 'Hello World'

# %% [markdown]
# # *Operators*

# %% [markdown]
# #### Operators calculation ya comparison karte hain.

# %% [markdown]
# #### +   Addition
# #### -   Subtraction
# #### *   Multiplication
# #### /   Division
# #### //  Floor division
# #### %   Modulus
# #### **  Power

# %% [markdown]
# ### Comparison Operators
# #### ==
# #### !=
# #### >
# #### <
# #### >=
# #### <=

# %% [markdown]
# ### Logical Operators
# #### and
# #### or
# #### not

# %% [markdown]
# # *Variables*

# %% [markdown]
# ##### Rules:
#
# ##### Number se start nahi ho sakta
#
# ##### Space allowed nahi
#
# ##### Keywords use nahi kar sakte

# %%
abdulrehman = 10
name = "Ali"

# %% [markdown]
# # *Keywords*

# %% [markdown]
# ##### if
# ##### else
# ##### for
# ##### while
# ##### True
# ##### False
# ##### None
