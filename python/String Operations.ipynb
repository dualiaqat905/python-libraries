# %% [markdown]
# # String Operations

# %% [markdown]
# #### Q: String Kya Hoti Hai?
# ##### Ans: string = Text Data

# %%
name = "Hira"
city = 'Lahore'

# %%
print(name)
print(city)
# Out:
# Hira
# Lahore

# %%
print(name,city)
# Out:
# Hira Lahore

# %% [markdown]
# ### 1) String Concatenation (Join Karna)

# %%
first = "AI"
second = "Engineer"
print(type(first))
print(first + " " + second)
# Out:
# <class 'str'>
# AI Engineer

# %% [markdown]
# ### 2) String Repetition

# %%
print("Hire " * 3)
# Out:
# Hire Hire Hire

# %% [markdown]
# ### 3) Indexing (Character Access Karna)

# %%
word = "Python"
print(word[4])
# Out:
# o

# %%
print(word[-2])
# Out:
# o

# %% [markdown]
# ### 4) Slicing (Part Extract Karna)

# %%
word = "Artificial Intelligence"

print(word[0:10])
# means 5 wala index include nahe ho ga
# Out:
# Artificial

# %% [markdown]
# ### 5) Length of String

# %%
text = "Machine "
print(len(text))
# Out:
# 8

# %% [markdown]
# ### 6) String Methods

# %%
text = "python  automation"
print(text.upper())
print(text.lower())
print(text.strip())
# Out:
# PYTHON  AUTOMATION
# python  automation
# python  automation

# %%
# Strip (Spaces Remove)
text = "   AI   "
print(text.strip())
# Strip (Spaces Remove)
text = "Hello AI"
print(text.replace("AI", "World"))
# Replace
text = "Hello AI"
print(text.replace("AI", "World"))
# Split
text = "AI is powerful"
print(text.split())
# Find
text = "Artificial Intelligence"
print(text.find("Intelligence"))
# Out:
# AI
# Hello World
# Hello World
# ['AI', 'is', 'powerful']
# 11

# %% [markdown]
# ### 7) String Formatting

# %%
# Old Style
name = "Hira"
age = 20
# print(name + age) Error
print("My name is", name, "and I am", age)
# Out:
# My name is Hira and I am 20

# %%
# f-String (Best Method)
print(f"My name is {name} and I am {age}")
# Out:
# My name is Hira and I am 20

# %% [markdown]
# ### 8) Checking in String

# %%
text = "AI Engineer"

print("AI" in text)
# Out:
# True

# %% [markdown]
# ### 9) Escape Characters

# %%
print("Hello\nWorld")
print("Hello\tWorld")
print("Hello\"World")
print("HelloWorld")
# Out:
# Hello
# World
# Hello	World
# Hello"World
# HelloWorld

# %% [raw]
# \n  new line
# \t  tab
# \"  double quote

# %%
a = 5
print(type(a))
# Out:
# <class 'int'>

# %%
a = 2 + 2j
print(type(a))
# Out:
# <class 'complex'>
