# %% [markdown]
# # *While, for loops and use of enumerate*

# %% [markdown]
# # While Loop

# %%
👉 Jab tak condition True ho, loop chalta rehta hai

# %%
while condition:
    code

# %%
i = 1

while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # For Loop

# %%
👉 Sequence par iterate karta hai (list, string, range, etc.)

# %%
for d in range(5):
    print(d)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits = ["apple", "banana", "mango"]

for f in fruits:
    print(f)
# Out:
# apple
# banana
# mango

# %% [markdown]
# # enumerate() ka Use

# %%
👉 Index + value dono deta hai 🔥

# %%
fruits = ["apple", "banana", "mango"]

for index, value in enumerate(fruits):
    print(index, value)
# Out:
# 0 apple
# 1 banana
# 2 mango

# %% [markdown]
# # Nested Loops

# %%
for i in range(3):
    for j in range(2):
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %% [markdown]
# # List Comprehension

# %% [raw]
# 👉 Short & powerful way list banane ka

# %%
squares = [x*x for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
evens = [x for x in range(10) if x % 2 == 0]
print(evens)
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# # Iterables

# %% [raw]
# 👉 Woh objects jin par loop chal sakta hai
#
# Examples:
#
# ✔ list
# ✔ tuple
# ✔ string
# ✔ set
# ✔ dictionary
# ✔ range

# %%
for ch in "HELLO":
    print(ch)
# Out:
# H
# E
# L
# L
# O

# %% [markdown]
# # Iterators

# %% [raw]
# 👉 Object jo next() se values deta hai step by step

# %%
nums = [10, 20, 30]

it = iter(nums)

print(next(it))
print(next(it))
print(next(it))
# Out:
# 10
# 20
# 30

# %% [raw]
# Iterable vs Iterator (Simple)
#
# 👉 Iterable = collection
# 👉 Iterator = one-by-one dene wala object
