# %% [markdown]
# #  Input and Type casting Comments

# %% [markdown]
# ### Input (User se Data Lena)

# %%
input()
# Out:
#  Hello
# 'Hello'

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name:  ABdul
# ABdul

# %% [raw]
# input() hamesha string return karta ha

# %%
a = input("Enter number: ")
b = input("Enter number: ")

print(a + b)

# %% [markdown]
# ### Type Casting (Data Type Change Karna)

# %%
num = int(input("Enter number: "))
# Out:
# Enter number:  2

# %%
num1 = int(input("Enter number: "))
num2 = int(input("Enter number: "))
print(num1+num2)
# Out:
# Enter number:  2
# Enter number:  2
# 4

# %% [markdown]
# ### Comments

# %% [markdown]
# #### Comments code explain karne ke liye hote hain.
#
# #### Python unko ignore karta hai.

# %% [markdown]
# ### Single Line Comment

# %%
# This is a comment

# %%
# Calculate area
radius = 5

# %% [markdown]
# ### Multi-Line Comment

# %%
"""
This is
multi-line
comment
"""
# Out:
# '\nThis is\nmulti-line\ncomment\n'

# %%
'''
Multi-line comment
'''
# Out:
# '\nMulti-line comment\n'
