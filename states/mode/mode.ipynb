# %%
import statistics as stat

data = [10,20,20,20,20,10,10,14,6,7,3,2,410,10]
mode = stat.multimode(data)
print(mode)
# Out:
# [10, 20]

# %%
import statistics as stat

data = [10,20,10,10,14,6,7,3,2,410,10]
mode = stat.mode(data)
print(mode)
# Out:
# 10

# %%
from scipy import stats

data = [10,20,20,10,80,10,46,64]

mode = stats.mode(data)
#sub sy choti value write ker dy ga 
# agr hum multimode use kerty to sari values a ajni thi
print(mode)
# Out:
# ModeResult(mode=np.int64(10), count=np.int64(3))

# %%
import statistics as stat

marks = [85, 90, 78, 92, 88, 90, 76, 95, 90, 82]

mode_marks = stat.mode(marks)

print( mode_marks)
# Out:
# 90
