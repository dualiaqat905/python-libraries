# %% [markdown]
# # range

# %%
#1
marks = [78, 85, 92, 88, 76, 95, 89, 90]
range_marks = max(marks) - min(marks)

print( range_marks)
# Out:
# 19

# %%
#2
age=[12,13,14,15,16]
range=max(age)-min(age)
print(range)
# Out:
# 4
